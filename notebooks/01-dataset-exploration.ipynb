# %% [markdown]
# We first import a part of the dataset (we're not gonna use the whole dataset for now)

# %%
from datasets import load_dataset

train_dataset = load_dataset(
  "json", 
  data_files="./../data/dataset/python/train.jsonl",
  split="train"
)
# Out:
# Generating train split: 251820 examples [00:01, 144802.63 examples/s]
