# %% [markdown]
# We first import the python dataset

# %%
from datasets import load_dataset

train_dataset = load_dataset(
  "json", 
  data_files="./../data/raw/dataset/python/train.jsonl",
  split="train"
)

val_dataset = load_dataset(
  "json", 
  data_files="./../data/raw/dataset/python/valid.jsonl",
  split="train"
)

test_dataset = load_dataset(
  "json", 
  data_files="./../data/raw/dataset/python/test.jsonl",
  split="train"
)

# %%
print(train_dataset)
print(val_dataset)
print(test_dataset)
# Out:
# Dataset({
#     features: ['repo', 'path', 'func_name', 'original_string', 'language', 'code', 'code_tokens', 'docstring', 'docstring_tokens', 'sha', 'url', 'partition'],
#     num_rows: 251820
# })
# Dataset({
#     features: ['repo', 'path', 'func_name', 'original_string', 'language', 'code', 'code_tokens', 'docstring', 'docstring_tokens', 'sha', 'url', 'partition'],
#     num_rows: 13914
# })
# Dataset({
#     features: ['repo', 'path', 'func_name', 'original_string', 'language', 'code', 'code_tokens', 'docstring', 'docstring_tokens', 'sha', 'url', 'partition'],
#     num_rows: 14918
# })

# %%
import pandas as pd

df = pd.DataFrame(train_dataset)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251820 entries, 0 to 251819
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   repo              251820 non-null  object
#  1   path              251820 non-null  object
#  2   func_name         251820 non-null  object
#  3   original_string   251820 non-null  object
#  4   language          251820 non-null  object
#  5   code              251820 non-null  object
#  6   code_tokens       251820 non-null  object
#  7   docstring         251820 non-null  object
#  8   docstring_tokens  251820 non-null  object
#  9   sha               251820 non-null  object
#  10  url               251820 non-null  object
#  11  partition         251820 non-null  object
# dtypes: object(12)
# memory usage: 23.1+ MB

# %% [markdown]
# We can see the dataframe doesn't contain null-objects, as the CodeXGLUE dataset is a polished version of a CodeSearchNet dataset.

# %%
df.shape
# Out:
# (251820, 12)

# %%
train_dataset[0]
# Out:
# {'repo': 'smdabdoub/phylotoast',
#  'path': 'phylotoast/util.py',
#  'func_name': 'split_phylogeny',
#  'original_string': 'def split_phylogeny(p, level="s"):\n    """\n    Return either the full or truncated version of a QIIME-formatted taxonomy string.\n\n    :type p: str\n    :param p: A QIIME-formatted taxonomy string: k__Foo; p__Bar; ...\n\n    :type level: str\n    :param level: The different level of identification are kingdom (k), phylum (p),\n                  class (c),order (o), family (f), genus (g) and species (s). If level is\n                  not provided, the default level of identification is species.\n\n    :rtype: str\n    :return: A QIIME-formatted taxonomy string up to the classification given\n            by param level.\n    """\n    level = level+"__"\n    result = p.split(level)\n    return result[0]+level+result[1].split(";")[0]',
#  'language': 'python',
# ...
